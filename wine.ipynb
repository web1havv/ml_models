# %% [markdown]
# <a href="https://colab.research.google.com/github/web1havv/ml_models/blob/main/wine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import accuracy_score

# %%
wine_dataset=pd.read_csv("/content/winequality-red.csv")

# %%
wine_dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_dataset.shape
# Out:
# (1599, 12)

# %%
wine_dataset.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wine_dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
sns.catplot(x='quality',data= wine_dataset,kind='count')

# %%
sns.barplot(x='quality',y="volatile acidity",data=wine_dataset)
# Out:
# <Axes: xlabel='quality', ylabel='volatile acidity'>

# %%
sns.barplot(x="quality",y='citric acid',data=wine_dataset)
# Out:
# <Axes: xlabel='quality', ylabel='citric acid'>

# %%
correlation =wine_dataset.corr()

# %%
sns.heatmap(correlation,cbar=True,cmap='Blues',annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Data pre processing

# %%
X=wine_dataset.drop('quality',axis=1)

# %% [markdown]
# Binarisation the data

# %%
Y=wine_dataset['quality']. apply(lambda y_value:1 if y_value >=7 else 0)

# %%
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1594    0
# 1595    0
# 1596    0
# 1597    0
# 1598    0
# Name: quality, Length: 1599, dtype: int64

# %%
#train and test split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,train_size=0.2)

# %% [markdown]
# Model Training :
# Random Forest Algorithm

# %%
model= RandomForestClassifier()

# %%
model.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# Accuracy score

# %%
X_test.prediction=model.predict(X_test)
# Out:
# <ipython-input-46-96f7021fc384>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   X_test.prediction=model.predict(X_test)

# %%
test_data_accuracy=accuracy_score(X_test.prediction,Y_test)

# %%
test_data_accuracy
# Out:
# 0.878125

# %%
X_train.prediction=model.predict(X_train)
# Out:
# <ipython-input-49-a30c5694964b>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   X_train.prediction=model.predict(X_train)

# %%
train_data_accuracy=accuracy_score(X_train.prediction,Y_train)

# %%
train_data_accuracy
# Out:
# 1.0

# %%
input_data=(11.3,0.62,0.67,5.2,0.086,6.0,19.0,0.9988,3.22,0.69,13.4)
input_data_as_numpy_array=np.asarray(input_data)

# %%
#for array not to confuse you have to make it from 1 to -1
input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)

# %%
prediction=model.predict(input_data_reshaped)

if (prediction == 1):
  print('Wine quality good')
else:
  print("bad quality wine")
# Out:
# Wine quality good
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
